# %%
# NIM/Nama  : 16521040/Kenneth Ezekiel Suprantoni
# Tanggal   : 01/11/2021
# Deskripsi : P 01 Praktikum Pengenalan Komputasi: Analisa dan Visualisasi Data

# Algoritma

import pandas as pd

df = pd.read_csv('P05-02.csv')

# print(df)

print("1. Banyaknya data")
print(len(df), "Baris")
print(len(df.columns), "Kolom")
print("")
tax_max = df['property_tax'].max()
print("2. Pajak bangunan per tahun terbesar")
print(tax_max)
print("")
print("3. 5 Rumah dengan harga sewa per tahun terbesar")
print(df.sort_values(['rent_amount'], ascending=[0])[:5])
print("")
print("4. Rumah yang berada di Rio de Janeiro")
print(df.loc[df['city'] == 'Rio de Janeiro'])
print("")
print("5. Nilai korelasi antara jumlah tempat parkir dan pajak tanah per tahun")
corr_num = df['parking_spaces'].corr(df['homeowner_tax'])
# print(df['parking_spaces'], df['homeowner_tax'])
print(corr_num)
print("dapat disimpulkan karena angka korelasi antara jumlah tempat parkir dan pajak tanah per tahun bahwa")
print("kedua variabel tersebut tidak berkorelasi, yang berarti bahwa tidak ada hubungan antara kedua variabel tersebut")
print("saat jumlah tempat parkir banyak, tidak pasti bahwa pajak tanah per tahun tinggi juga")
# Out:
# 1. Banyaknya data
# 8231 Baris
# 13 Kolom
#
# 2. Pajak bangunan per tahun terbesar
# 313700
#
# 3. 5 Rumah dengan harga sewa per tahun terbesar
#            city  area  rooms  bathroom  parking_spaces  floor     animal  \
# 1978  Sao Paulo    80      2         1               1      1      acept
# 933   Sao Paulo   315      3         5               2     14  not acept
# 2166  Sao Paulo   285      4         5               4      6      acept
# 1302  Sao Paulo   410      4         5               5      1      acept
# 129   Sao Paulo   660      4         5               5     12      acept
#
#           furniture  homeowner_tax  rent_amount  property_tax  fire_insurance  \
# 1978  not furnished            875        24000             0             305
# 933   not furnished           4300        20000           959             254
# 2166      furnished         200000        20000          1834             254
# ...
