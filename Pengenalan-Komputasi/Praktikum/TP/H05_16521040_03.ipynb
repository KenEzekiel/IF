# %%
# NIM/Nama  : 16521040/Kenneth Ezekiel Suprantoni
# Tanggal   : 29/11/2021
# Deskripsi : TP 03 Praktikum Pengenalan Komputasi: Analisa dan Visualisasi Data

# Algoritma

import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('H05.csv')
# print(df)

print("1. Histogram distribusi nilai matematika")
df[['nilai_mat']].plot(kind="hist",bins=[0, 20, 40, 60, 80, 100], rwidth = 0.9)
# plt.hist(df['nilai_mat'], bins=[0, 20, 40, 60, 80, 100], rwidth=0.9, color="red")
# Out:
#                           nama fakultas  nilai_mat  nilai_kim  nilai_fis
# 0         Farhan Fathur Rahman    FMIPA      57.21      34.14      38.93
# 1               Steven Margono    FMIPA      67.43      51.50      57.20
# 2                 Ryan Sentosa    SAPPK      90.62      37.38      40.73
# 3         Muhajah Babny Muslim    FMIPA      72.31      38.80      44.79
# 4             Alvin Natawiguna     FTSL      65.45      57.67      56.39
# ...                        ...      ...        ...        ...        ...
# 5130               Khoirrashif    SITHR      66.14      46.82      56.74
# 5131      Jefri Hendri Adriano     FTSL      53.68      34.74      33.76
# 5132               Iki Hidayat     FITB      69.63      35.04      37.65
# 5133  Muhammad Nashir Sitompul      FTI      79.69      39.06      50.17
# 5134     Billy Richardo Sagala     STEI      68.68      51.23      66.18
#
# [5135 rows x 5 columns]
# 1. Histogram distribusi nilai matematika
# ...

# %%
# NIM/Nama  : 16521040/Kenneth Ezekiel Suprantoni
# Tanggal   : 29/11/2021
# Deskripsi : TP 03 Praktikum Pengenalan Komputasi: Analisa dan Visualisasi Data

# Algoritma

import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('H05.csv')
# print(df)

print("2. Diagram batang horizontal banyaknya mahasiswa masing-masing fakultas")
df['fakultas'].value_counts().plot(kind = "bar", width = 0.9)
# Out:
#                           nama fakultas  nilai_mat  nilai_kim  nilai_fis
# 0         Farhan Fathur Rahman    FMIPA      57.21      34.14      38.93
# 1               Steven Margono    FMIPA      67.43      51.50      57.20
# 2                 Ryan Sentosa    SAPPK      90.62      37.38      40.73
# 3         Muhajah Babny Muslim    FMIPA      72.31      38.80      44.79
# 4             Alvin Natawiguna     FTSL      65.45      57.67      56.39
# ...                        ...      ...        ...        ...        ...
# 5130               Khoirrashif    SITHR      66.14      46.82      56.74
# 5131      Jefri Hendri Adriano     FTSL      53.68      34.74      33.76
# 5132               Iki Hidayat     FITB      69.63      35.04      37.65
# 5133  Muhammad Nashir Sitompul      FTI      79.69      39.06      50.17
# 5134     Billy Richardo Sagala     STEI      68.68      51.23      66.18
#
# [5135 rows x 5 columns]
# ...

# %%
# NIM/Nama  : 16521040/Kenneth Ezekiel Suprantoni
# Tanggal   : 29/11/2021
# Deskripsi : TP 03 Praktikum Pengenalan Komputasi: Analisa dan Visualisasi Data

# Algoritma

import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('H05.csv')
# print(df)

print("3. Diagram pie banyaknya mahasiswa masing-masing fakultas")
df['fakultas'].value_counts().plot(kind = "pie")
# Out:
#                           nama fakultas  nilai_mat  nilai_kim  nilai_fis
# 0         Farhan Fathur Rahman    FMIPA      57.21      34.14      38.93
# 1               Steven Margono    FMIPA      67.43      51.50      57.20
# 2                 Ryan Sentosa    SAPPK      90.62      37.38      40.73
# 3         Muhajah Babny Muslim    FMIPA      72.31      38.80      44.79
# 4             Alvin Natawiguna     FTSL      65.45      57.67      56.39
# ...                        ...      ...        ...        ...        ...
# 5130               Khoirrashif    SITHR      66.14      46.82      56.74
# 5131      Jefri Hendri Adriano     FTSL      53.68      34.74      33.76
# 5132               Iki Hidayat     FITB      69.63      35.04      37.65
# 5133  Muhammad Nashir Sitompul      FTI      79.69      39.06      50.17
# 5134     Billy Richardo Sagala     STEI      68.68      51.23      66.18
#
# [5135 rows x 5 columns]
# 3. Diagram pie banyaknya mahasiswa masing-masing fakultas
# ...

# %%
# NIM/Nama  : 16521040/Kenneth Ezekiel Suprantoni
# Tanggal   : 29/11/2021
# Deskripsi : TP 03 Praktikum Pengenalan Komputasi: Analisa dan Visualisasi Data

# Algoritma

import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('H05.csv')
# print(df)

print("4. Manakah fakultas dengan mahasiswa terbanyak? Manakah diagram yang lebih baik menampilkan fakultas dengan mahasiswa terbanyak dan mengapa?")
fakultas_max = df['fakultas'].value_counts().idxmax()
print(fakultas_max)
print("Bar chart lebih baik menampilkan fakultas dengan mahasiswa terbanyak karena variabel fakultas yang banyak.")
print("Jumlah frekuensi dapat lebih terlihat dan terwakilkan dengan bar chart,")
print("sedangkan pie chart dapat mewakilkan data dengan variabel yang lebih sedikit dengan lebih baik karena kita dapat melihat persebaran mayoritas dan minoritas data.")
print("")
print("5. Scatter plot dengan nilai kimia sebagai x dan fisika sebagai y")
df.plot(kind="scatter", x="nilai_kim", y="nilai_fis")
# Out:
#                           nama fakultas  nilai_mat  nilai_kim  nilai_fis
# 0         Farhan Fathur Rahman    FMIPA      57.21      34.14      38.93
# 1               Steven Margono    FMIPA      67.43      51.50      57.20
# 2                 Ryan Sentosa    SAPPK      90.62      37.38      40.73
# 3         Muhajah Babny Muslim    FMIPA      72.31      38.80      44.79
# 4             Alvin Natawiguna     FTSL      65.45      57.67      56.39
# ...                        ...      ...        ...        ...        ...
# 5130               Khoirrashif    SITHR      66.14      46.82      56.74
# 5131      Jefri Hendri Adriano     FTSL      53.68      34.74      33.76
# 5132               Iki Hidayat     FITB      69.63      35.04      37.65
# 5133  Muhammad Nashir Sitompul      FTI      79.69      39.06      50.17
# 5134     Billy Richardo Sagala     STEI      68.68      51.23      66.18
#
# [5135 rows x 5 columns]
# ...
